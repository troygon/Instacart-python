# %% [markdown]
# # 01 Importing Libraries

# %%
# Importing libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02 Importing Dataframe

# %%
# Importing products dataframe
path = r'C:\Users\vacgo\Documents\Achievement 4\Instacart Basket Analysis\02 Data'
ords_prods_merge = pd.read_pickle(os.path.join(path, 'Prepared Data', 'ords_prods_merge_latest_20241115_clean.pkl'))

# %%
ords_prods_merge.isnull().sum()
# Out:
# order_id                       0
# user_id                        0
# order_number                   0
# order_day_of_week              0
# order_hour_of_day              0
# days_from_last_order     2076096
# new_customer                   0
# product_id                     0
# add_to_cart_order              0
# reordered                      0
# product_name                   0
# aisle_id                       0
# department_id                  0
# prices                         0
# merge_2                        0
# price_range_loc                0
# busiest_day                    0
# busiest_days_new               0
# busiest_period_of_day          0
# dtype: int64

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_from_last_order  new_customer  product_id  add_to_cart_order  \
# 0                   NaN          True         196                  1
# 1                   NaN          True       14084                  2
# 2                   NaN          True       12427                  3
# 3                   NaN          True       26088                  4
# 4                   NaN          True       26405                  5
#
#    reordered                             product_name  aisle_id  \
# ...

# %%
ords_prods_merge.shape
# Out:
# (32404859, 19)

# %% [markdown]
# # 03 Task

# %%
# Find the agg mean of order_number, groupby department_id

ords_prods_merge.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.457838
# 2     17.277920
# 3     17.170395
# 4     17.811403
# 5     15.215751
# 6     16.439806
# 7     17.225802
# 8     15.340650
# 9     15.895474
# 10    20.197148
# 11    16.170638
# 12    15.887671
# 13    16.583536
# 14    16.773669
# 15    16.165037
# 16    17.665606
# 17    15.694469
# 18    19.310397
# 19    17.177343
# 20    16.473447
# 21    22.902379
# Name: order_number, dtype: float64

# %%
# Check the subset again
df_subset = ords_prods_merge[:1000000]

# %%
df_subset.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     14.800024
# 2     17.091743
# 3     17.913544
# 4     17.893092
# 5     15.214270
# 6     15.382135
# 7     17.694027
# 8     16.458105
# 9     15.957363
# 10    20.091818
# 11    16.482026
# 12    15.615061
# 13    16.484023
# 14    17.524632
# 15    15.691875
# 16    18.014071
# 17    16.150593
# 18    19.602850
# 19    17.631340
# 20    17.138607
# 21    21.956893
# Name: order_number, dtype: float64

# %% [markdown]
# #### As expexted, the mean will vary but nothing stands out with a very big deviation from the subset mean

# %%
# Creating loyalty flag for customers
# Group by user_id for customer loyalty
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform('max')

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_from_last_order  new_customer  product_id  add_to_cart_order  \
# 0                   NaN          True         196                  1
# 1                   NaN          True       14084                  2
# 2                   NaN          True       12427                  3
# 3                   NaN          True       26088                  4
# 4                   NaN          True       26405                  5
#
#    reordered                             product_name  aisle_id  \
# ...

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (df['max_order'] > 10) , 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
ords_prods_merge.groupby(['loyalty_flag']).user_id.nunique()
# Out:
# loyalty_flag
# Loyal customer       17017
# New customer        112328
# Regular customer     76864
# Name: user_id, dtype: int64

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_from_last_order  new_customer  product_id  add_to_cart_order  \
# 0                   NaN          True         196                  1
# 1                   NaN          True       14084                  2
# 2                   NaN          True       12427                  3
# 3                   NaN          True       26088                  4
# 4                   NaN          True       26405                  5
#
#    reordered  ... aisle_id  department_id  prices  merge_2    price_range_loc  \
# ...

# %%
ords_prods_merge.isnull().sum()
# Out:
# order_id                       0
# user_id                        0
# order_number                   0
# order_day_of_week              0
# order_hour_of_day              0
# days_from_last_order     2076096
# new_customer                   0
# product_id                     0
# add_to_cart_order              0
# reordered                      0
# product_name                   0
# aisle_id                       0
# department_id                  0
# prices                         0
# merge_2                        0
# price_range_loc                0
# busiest_day                    0
# busiest_days_new               0
# busiest_period_of_day          0
# max_order                      0
# loyalty_flag                   0
# dtype: int64

# %%
# Check Loyalty flag
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number','max_order']].head(60)
# Out:
#     user_id      loyalty_flag  order_number  max_order
# 0         1      New customer             1         10
# 1         1      New customer             1         10
# 2         1      New customer             1         10
# 3         1      New customer             1         10
# 4         1      New customer             1         10
# 5         1      New customer             2         10
# 6         1      New customer             2         10
# 7         1      New customer             2         10
# 8         1      New customer             2         10
# 9         1      New customer             2         10
# 10        1      New customer             2         10
# 11        1      New customer             3         10
# 12        1      New customer             3         10
# 13        1      New customer             3         10
# 14        1      New customer             3         10
# 15        1      New customer             3         10
# ...

# %%
# Remove prices of more than 100

#ords_prods_merge.loc[ords_prods_merge['prices'] >100, 'prices'] = np.nan

# %%
ords_prods_merge.isnull().sum()
# Out:
# order_id                       0
# user_id                        0
# order_number                   0
# order_day_of_week              0
# order_hour_of_day              0
# days_from_last_order     2076096
# new_customer                   0
# product_id                     0
# add_to_cart_order              0
# reordered                      0
# product_name                   0
# aisle_id                       0
# department_id                  0
# prices                         0
# merge_2                        0
# price_range_loc                0
# busiest_day                    0
# busiest_days_new               0
# busiest_period_of_day          0
# max_order                      0
# loyalty_flag                   0
# dtype: int64

# %%
# Checking the spending habits of the 3 types of customers based on prices
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# #### New customers has the highest average price, while the loyal customers has the lowest average price of products. It might mean that the new customers are buying more products while the loyal customers come back for certain products only.

# %%
# Creating spending flag for customers
# Group by user_id for spending flag
ords_prods_merge['ave_spent'] = ords_prods_merge.groupby(['user_id'])['prices'].transform('mean')

# %%
ords_prods_merge.head(60)
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                  2                  8
# 1    2539329        1             1                  2                  8
# 2    2539329        1             1                  2                  8
# 3    2539329        1             1                  2                  8
# 4    2539329        1             1                  2                  8
# 5    2398795        1             2                  3                  7
# 6    2398795        1             2                  3                  7
# 7    2398795        1             2                  3                  7
# 8    2398795        1             2                  3                  7
# 9    2398795        1             2                  3                  7
# 10   2398795        1             2                  3                  7
# 11    473747        1             3                  3                 12
# ...

# %%
ords_prods_merge.loc[ords_prods_merge['ave_spent'] < 10, 'spender'] = 'Low spender'

# %%
ords_prods_merge.loc[ords_prods_merge['ave_spent'] >= 10, 'spender'] = 'High spender'

# %%
ords_prods_merge['spender'].value_counts()
# Out:
# spender
# Low spender     31770614
# High spender      634245
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'spender']].tail(60)
# Out:
#           user_id      spender
# 32404799   206209  Low spender
# 32404800   206209  Low spender
# 32404801   206209  Low spender
# 32404802   206209  Low spender
# 32404803   206209  Low spender
# 32404804   206209  Low spender
# 32404805   206209  Low spender
# 32404806   206209  Low spender
# 32404807   206209  Low spender
# 32404808   206209  Low spender
# 32404809   206209  Low spender
# 32404810   206209  Low spender
# 32404811   206209  Low spender
# 32404812   206209  Low spender
# 32404813   206209  Low spender
# 32404814   206209  Low spender
# 32404815   206209  Low spender
# 32404816   206209  Low spender
# 32404817   206209  Low spender
# 32404818   206209  Low spender
# 32404819   206209  Low spender
# 32404820   206209  Low spender
# 32404821   206209  Low spender
# 32404822   206209  Low spender
# 32404823   206209  Low spender
# 32404824   206209  Low spender
# 32404825   206209  Low spender
# 32404826   206209  Low spender
# 32404827   206209  Low spender
# ...

# %%
# Creating frequent customer flag for Marketing
ords_prods_merge['median_days_to_order'] = ords_prods_merge.groupby(['user_id'])['days_from_last_order'].transform('median')

# %%
ords_prods_merge.loc[ords_prods_merge['median_days_to_order'] > 20, 'frequent_cust'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_days_to_order'] <= 20) & (df['median_days_to_order'] > 10), 'frequent_cust'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['median_days_to_order'] <= 10, 'frequent_cust'] = 'Frequent customer'

# %%
ords_prods_merge['frequent_cust'].value_counts()
# Out:
# frequent_cust
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# Name: count, dtype: int64

# %%
ords_prods_merge.groupby(['frequent_cust']).user_id.nunique()
# Out:
# frequent_cust
# Frequent customer        86596
# Non-frequent customer    59619
# Regular customer         59993
# Name: user_id, dtype: int64

# %%
ords_prods_merge.head(60)
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                  2                  8
# 1    2539329        1             1                  2                  8
# 2    2539329        1             1                  2                  8
# 3    2539329        1             1                  2                  8
# 4    2539329        1             1                  2                  8
# 5    2398795        1             2                  3                  7
# 6    2398795        1             2                  3                  7
# 7    2398795        1             2                  3                  7
# 8    2398795        1             2                  3                  7
# 9    2398795        1             2                  3                  7
# 10   2398795        1             2                  3                  7
# 11    473747        1             3                  3                 12
# ...

# %% [markdown]
# # 04 Export Data

# %%
# Exporting the dataframe to pickle
ords_prods_merge.to_pickle(os.path.join(path, 'Prepared Data', 'ords_prods_merge_latest_20241115_2.pkl'))

# %%
ords_prods_merge.isnull().sum()
# Out:
# order_id                       0
# user_id                        0
# order_number                   0
# order_day_of_week              0
# order_hour_of_day              0
# days_from_last_order     2076096
# new_customer                   0
# product_id                     0
# add_to_cart_order              0
# reordered                      0
# product_name                   0
# aisle_id                       0
# department_id                  0
# prices                         0
# merge_2                        0
# price_range_loc                0
# busiest_day                    0
# busiest_days_new               0
# busiest_period_of_day          0
# max_order                      0
# loyalty_flag                   0
# ave_spent                      0
# spender                        0
# median_days_to_order           5
# frequent_cust                  5
# dtype: int64

# %%
ords_prods_merge.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'order_day_of_week',
#        'order_hour_of_day', 'days_from_last_order', 'new_customer',
#        'product_id', 'add_to_cart_order', 'reordered', 'product_name',
#        'aisle_id', 'department_id', 'prices', 'merge_2', 'price_range_loc',
#        'busiest_day', 'busiest_days_new', 'busiest_period_of_day', 'max_order',
#        'loyalty_flag', 'ave_spent', 'spender', 'median_days_to_order',
#        'frequent_cust'],
#       dtype='object')

# %%
ords_prods_merge['order_hour_of_day'].value_counts().sort_index()
# Out:
# order_hour_of_day
# 0      218769
# 1      115700
# 2       69375
# 3       51281
# 4       53242
# 5       87961
# 6      290493
# 7      891054
# 8     1718118
# 9     2454203
# 10    2761760
# 11    2736140
# 12    2618532
# 13    2660954
# 14    2689136
# 15    2662144
# 16    2535202
# 17    2087654
# 18    1636502
# 19    1258305
# 20     976156
# 21     795637
# 22     634225
# 23     402316
# Name: count, dtype: int64
